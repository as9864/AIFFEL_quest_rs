# %%
from transformers import pipeline


generator = pipeline(task="text-generation", model="gpt2")
outputs = generator(
    text_inputs="Machine learning is",
    max_length=20,
    num_return_sequences=3,
    pad_token_id=generator.tokenizer.eos_token_id
)
print(outputs)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# c:\Users\H11\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:138: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\H11\.cache\huggingface\hub\models--gpt2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# [transformers] Passing `generation_config` together with generation-related arguments=({'max_length', 'num_return_sequences', 'pad_token_id'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer GPT2Tokenizer. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
# [{'generated_text': "Machine learning is a powerful, but difficult, field. There are many factors that cause a person to become blind, including a lack of empathy, lack of experience with the sensory world, or a lack of social skills, including language, language-based interaction, or a lack of experience with emotion.\n\nBut there are many other factors that can cause blind people to become blind. A person who is blind may also experience a variety of mental conditions, including:\n\nIntense pain\n\nBrief or painful migraines\n\nHearing difficulties\n\nVomiting\n\nPossible allergies\n\nFrequent or severe infections\n\nChronic or chronic fatigue\n\nIf you are blind, you may experience a number of other problems. For example, people with a disability may experience a variety of cognitive problems including:\n\nSigns of visual impairment. For example, people with a disability may be able to see certain things in an abstract way. But people with a disability may be able to see the same things in a different way.\n\nTo address this issue, you may want to consider taking medications that improve your vision. You can read more about these medications here.\n\nIf you aren't blind, you may not feel any of these symptoms.\n"}, {'generated_text': 'Machine learning is a bit more complex than most people realize. For example, many of us are familiar with the notion that if you want to learn more about a particular problem, you have to be motivated to learn more. So it\'s a bit like reading a book at a library, as far as I know.\n\nBut that\'s just part of the experience of learning. There are many more ways to learn and learn about information, and there\'s a lot to learn from. The whole idea of learning is that you learn about something, and so when you are a student you learn about something else, and this is why you go to the library and read about things that you\'ve never seen before.\n\nMueller: Yes, this is very important. The more you learn, the more you learn about it. You have more fun doing this, and you learn more about the information. And the more you do this, the more fun it gets.\n\nNow, I know there\'s a lot of talk about the need for the brain to be "all-in" on certain things, and this is something that\'s been debated for a long time. You know, you\'re always saying, "Why don\'t we use the brain more for learning?" Well, there'}, {'generated_text': 'Machine learning is used to solve problems that are hard to predict or solve. It is therefore useful to understand how algorithms work, and what they can do.\n\nMany of the problems described in this book are not too difficult to solve. In fact, they are quite difficult to solve. Although some problems are difficult to solve on their own, they are not hard to solve when we apply the same kind of algorithms as above.\n\nIn this book, we will try to understand the algorithms that have been used to solve those problems. We will also try to understand how they work and what they can do.\n\nThe book also contains many more books about the different types of algorithms used by the industry. The book contains information on algorithms, as well as some other topics for those interested.\n\nIn the book, we will also summarize the main algorithms used by the industry.\n\nThe book also contains information about the different types of algorithms used by the industries. The book also contains information on how they work and what they can do.\n\nThe book also contains information about the different types of algorithms used by the industries. There are also many books about the different types of algorithms used by industry.\n\nIn conclusion, I hope this book has made the most of the'}]
