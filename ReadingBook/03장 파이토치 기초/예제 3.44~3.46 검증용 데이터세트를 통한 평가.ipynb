# %%
import torch
import pandas as pd
from torch import nn
from torch import optim
from torch.utils.data import Dataset, DataLoader, random_split

# %%
class CustomDataset(Dataset):
    def __init__(self, file_path):
        df = pd.read_csv(file_path)
        self.x = df.iloc[:, 0].values
        self.y = df.iloc[:, 1].values
        self.length = len(df)

    def __getitem__(self, index):
        x = torch.FloatTensor([self.x[index] ** 2, self.x[index]])
        y = torch.FloatTensor([self.y[index]])
        return x, y

    def __len__(self):
        return self.length

# %%
class CustomModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.layer = nn.Linear(2, 1)

    def forward(self, x):
        x = self.layer(x)
        return x

# %%
dataset = CustomDataset("../datasets/non_linear.csv")
dataset_size = len(dataset)
train_size = int(dataset_size * 0.8)
validation_size = int(dataset_size * 0.1)
test_size = dataset_size - train_size - validation_size

train_dataset, validation_dataset, test_dataset = random_split(dataset, [train_size, validation_size, test_size])
print(f"Training Data Size : {len(train_dataset)}")
print(f"Validation Data Size : {len(validation_dataset)}")
print(f"Testing Data Size : {len(test_dataset)}")

train_dataloader = DataLoader(train_dataset, batch_size=16, shuffle=True, drop_last=True)
validation_dataloader = DataLoader(validation_dataset, batch_size=4, shuffle=True, drop_last=True)
test_dataloader = DataLoader(test_dataset, batch_size=4, shuffle=True, drop_last=True)
# Out:
# Training Data Size : 160
# Validation Data Size : 20
# Testing Data Size : 20

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
model = CustomModel().to(device)
criterion = nn.MSELoss().to(device)
optimizer = optim.SGD(model.parameters(), lr=0.0001)

# %%
for epoch in range(10000):
    cost = 0.0

    for x, y in train_dataloader:
        x = x.to(device)
        y = y.to(device)

        output = model(x)
        loss = criterion(output, y)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        cost += loss

    cost = cost / len(train_dataloader)

    if (epoch + 1) % 1000 == 0:
        print(f"Epoch : {epoch+1:4d}, Model : {list(model.parameters())}, Cost : {cost:.3f}")
# Out:
# Epoch : 1000, Model : [Parameter containing:
# tensor([[ 3.1079, -1.7030]], device='cuda:0', requires_grad=True), Parameter containing:
# tensor([0.0350], device='cuda:0', requires_grad=True)], Cost : 0.184
# Epoch : 2000, Model : [Parameter containing:
# tensor([[ 3.1018, -1.7026]], device='cuda:0', requires_grad=True), Parameter containing:
# tensor([0.3154], device='cuda:0', requires_grad=True)], Cost : 0.099
# Epoch : 3000, Model : [Parameter containing:
# tensor([[ 3.1016, -1.7025]], device='cuda:0', requires_grad=True), Parameter containing:
# tensor([0.4317], device='cuda:0', requires_grad=True)], Cost : 0.084
# Epoch : 4000, Model : [Parameter containing:
# tensor([[ 3.0993, -1.7025]], device='cuda:0', requires_grad=True), Parameter containing:
# tensor([0.4800], device='cuda:0', requires_grad=True)], Cost : 0.083
# Epoch : 5000, Model : [Parameter containing:
# tensor([[ 3.1003, -1.7026]], device='cuda:0', requires_grad=True), Parameter containing:
# tensor([0.5000], device='cuda:0', requires_grad=True)], Cost : 0.082
# Epoch : 6000, Model : [Parameter containing:
# tensor([[ 3.0998, -1.7025]], device='cuda:0', requires_grad=True), Parameter containing:
# tensor([0.5082], device='cuda:0', requires_grad=True)], Cost : 0.082
# Epoch : 7000, Model : [Parameter containing:
# tensor([[ 3.1010, -1.7023]], device='cuda:0', requires_grad=True), Parameter containing:
# tensor([0.5117], device='cuda:0', requires_grad=True)], Cost : 0.080
# Epoch : 8000, Model : [Parameter containing:
# tensor([[ 3.1004, -1.7025]], device='cuda:0', requires_grad=True), Parameter containing:
# tensor([0.5131], device='cuda:0', requires_grad=True)], Cost : 0.082
# Epoch : 9000, Model : [Parameter containing:
# tensor([[ 3.1006, -1.7025]], device='cuda:0', requires_grad=True), Parameter containing:
# tensor([0.5136], device='cuda:0', requires_grad=True)], Cost : 0.085
# Epoch : 10000, Model : [Parameter containing:
# tensor([[ 3.1003, -1.7025]], device='cuda:0', requires_grad=True), Parameter containing:
# tensor([0.5139], device='cuda:0', requires_grad=True)], Cost : 0.083

# %%
with torch.no_grad():
    model.eval()
    for x, y in validation_dataloader:
        x = x.to(device)
        y = y.to(device)
        
        outputs = model(x)
        print(f"X : {x}")
        print(f"Y : {y}")
        print(f"Outputs : {outputs}")
        print("--------------------")
# Out:
# X : tensor([[ 7.2900,  2.7000],
#         [ 7.2900, -2.7000],
#         [54.7600, -7.4000],
#         [92.1600,  9.6000]], device='cuda:0')
# Y : tensor([[ 18.2600],
#         [ 27.6000],
#         [183.2400],
#         [269.8500]], device='cuda:0')
# Outputs : tensor([[ 18.5181],
#         [ 27.7118],
#         [182.8841],
#         [269.8913]], device='cuda:0')
# --------------------
# X : tensor([[27.0400, -5.2000],
#         [15.2100, -3.9000],
#         [25.0000,  5.0000],
#         [14.4400, -3.8000]], device='cuda:0')
# Y : tensor([[92.9100],
#         [54.0300],
#         [69.6700],
#         [52.0000]], device='cuda:0')
# Outputs : tensor([[93.1987],
#         [54.3091],
#         [69.5082],
#         [51.7516]], device='cuda:0')
# --------------------
# X : tensor([[ 0.4900,  0.7000],
#         [34.8100, -5.9000],
#         [ 5.7600,  2.4000],
#         [ 4.0000,  2.0000]], device='cuda:0')
# Y : tensor([[  0.8600],
#         [118.7100],
#         [ 13.8100],
#         [  9.2600]], device='cuda:0')
# Outputs : tensor([[  0.8413],
#         [118.4797],
#         [ 14.2854],
#         [  9.5099]], device='cuda:0')
# --------------------
# X : tensor([[ 8.4100,  2.9000],
#         [68.8900, -8.3000],
#         [11.5600,  3.4000],
#         [30.2500, -5.5000]], device='cuda:0')
# Y : tensor([[ 21.1800],
#         [228.1800],
#         [ 30.6800],
#         [103.5500]], device='cuda:0')
# Outputs : tensor([[ 21.6499],
#         [228.2233],
#         [ 30.5645],
#         [103.6614]], device='cuda:0')
# --------------------
# X : tensor([[56.2500,  7.5000],
#         [79.2100, -8.9000],
#         [ 9.6100, -3.1000],
#         [14.4400,  3.8000]], device='cuda:0')
# Y : tensor([[161.9400],
#         [260.8500],
#         [ 35.5700],
#         [ 38.7700]], device='cuda:0')
# Outputs : tensor([[162.1355],
#         [261.2397],
#         [ 35.5855],
#         [ 38.8123]], device='cuda:0')
# --------------------
